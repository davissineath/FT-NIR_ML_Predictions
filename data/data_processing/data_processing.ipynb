# %%
import pandas as pd
import glob

from processing import processing_pipeline, no_processing, processing

# %%
fps = [
    "../glucose_flour_mixes/0/*.csv", 
    "../glucose_flour_mixes/15/*.csv", 
    "../glucose_flour_mixes/25/*.csv",
    "../glucose_flour_mixes/35/*.csv", 
    "../glucose_flour_mixes/45/*.csv", 
    "../glucose_flour_mixes/50/*.csv",
    "../glucose_flour_mixes/75/*.csv", 
    "../glucose_flour_mixes/100/*.csv"
    ] # Path to folders for each height

labels = [0, 0.15, 0.25, 0.35, 0.45, 0.5, 0.75, 1] # Labels for each height/group

# %%
data = processing_pipeline(fps, labels)
cols_to_drop = [col for col in data.columns if col <= 4500]
data = data.drop(columns=cols_to_drop)
data
# Out:
# Processing ./glucose_flour_mixes/0/*.csv with label 0...
# Processing ./glucose_flour_mixes/15/*.csv with label 0.15...
# Processing ./glucose_flour_mixes/25/*.csv with label 0.25...
# Processing ./glucose_flour_mixes/35/*.csv with label 0.35...
# Processing ./glucose_flour_mixes/45/*.csv with label 0.45...
# Processing ./glucose_flour_mixes/50/*.csv with label 0.5...
# Processing ./glucose_flour_mixes/75/*.csv with label 0.75...
# Processing ./glucose_flour_mixes/100/*.csv with label 1...
# Wavenumber  4501.041   4504.898   4508.755   4512.612   4516.469   4520.326   \
# 0.0          0.368909   0.371250   0.365693   0.365159   0.360829   0.357576
# 0.0          0.174039   0.171243   0.155967   0.157244   0.160958   0.160517
# 0.0          0.136935   0.121657   0.128571   0.139961   0.128281   0.116669
# 0.0          0.406242   0.400763   0.402500   0.402956   0.405200   0.405639
# 0.0          0.362856   0.353994   0.346843   0.346984   0.347116   0.345381
# ..                ...        ...        ...        ...        ...        ...
# 1.0          0.555258   0.556772   0.560092   0.556223   0.554091   0.554223
# 1.0          0.586003   0.593413   0.589558   0.598289   0.603600   0.606577
# 1.0          0.579945   0.592876   0.584950   0.580428   0.582088   0.575230
# 1.0          0.570594   0.573988   0.576377   0.572245   0.578236   0.583994
# 1.0          0.560474   0.554475   0.554789   0.558621   0.564401   0.570781
#
# Wavenumber  4524.183   4528.040   4531.896   4535.754   ...  9966.316   \
# 0.0          0.355040   0.356554   0.354889   0.347379  ...   0.184542
# 0.0          0.163248   0.159695   0.159699   0.164543  ...   0.148533
# 0.0          0.125559   0.130501   0.128288   0.118640  ...   0.061725
# 0.0          0.394606   0.392809   0.388402   0.392009  ...   0.068231
# 0.0          0.343901   0.345708   0.334150   0.325251  ...   0.142166
# ..                ...        ...        ...        ...  ...        ...
# 1.0          0.552431   0.560476   0.564071   0.570377  ...   0.062581
# 1.0          0.610223   0.606317   0.603439   0.606896  ...   0.123145
# 1.0          0.575615   0.583541   0.583483   0.592932  ...   0.080313
# 1.0          0.586108   0.586958   0.589191   0.591778  ...   0.045519
# 1.0          0.578055   0.568319   0.572939   0.576329  ...   0.071323
#
# Wavenumber  9970.173   9974.030   9977.887   9981.744   9985.601   9989.458   \
# 0.0          0.178153   0.177718   0.180572   0.173209   0.168235   0.171978
# 0.0          0.146436   0.142626   0.145708   0.151303   0.145216   0.132038
# 0.0          0.052813   0.050689   0.058184   0.062055   0.062467   0.065904
# 0.0          0.065292   0.067868   0.072777   0.068126   0.062028   0.065154
# 0.0          0.144459   0.144330   0.146200   0.151574   0.146458   0.141956
# ..                ...        ...        ...        ...        ...        ...
# 1.0          0.061989   0.061168   0.060477   0.058960   0.063098   0.066309
# 1.0          0.124818   0.124524   0.126314   0.127380   0.129594   0.127124
# 1.0          0.077472   0.077117   0.078712   0.079774   0.082540   0.079884
# 1.0          0.042929   0.042077   0.044491   0.044328   0.043269   0.042787
# 1.0          0.067944   0.067224   0.065638   0.066325   0.070320   0.072691
#
# Wavenumber  9993.314   9997.172   10001.030
# 0.0          0.176712   0.172280   0.168966
# 0.0          0.135004   0.136618   0.140038
# 0.0          0.058885   0.050026   0.049251
# 0.0          0.067731   0.067351   0.065652
# 0.0          0.135055   0.132481   0.141057
# ..                ...        ...        ...
# 1.0          0.062699   0.063096   0.061129
# 1.0          0.126583   0.124586   0.125121
# 1.0          0.077831   0.076295   0.074526
# 1.0          0.042323   0.040255   0.040373
# 1.0          0.070655   0.065343   0.063607
#
# [167 rows x 1427 columns]

# %%
mean_data= pd.DataFrame(columns=data.columns)
for ind in set(data.index.to_list()):
    mean_data.loc[ind] = data.loc[ind].mean()

mean_data.to_csv("mean_data.csv", index=True)
